# %%
import folium
import math
from folium.plugins import HeatMap
import pandas as pd

map1 = folium.Map([19.2, -99.14], tiles='cartodbpositron', zoom_start=12)
data_confirmed        = pd.read_csv('tabula-Tabla_casos_positivos_COVID-19_resultado_InDRE_2020.04.03.csv')
data_confrimed_head()

# %%
map1 = folium.Map([19.2, -99.14], tiles='cartodbpositron', zoom_start=6)

data = []
for index, row in data_confirmed.iterrows():
    if not math.isnan(row['LAT']) and not math.isnan(row['LONG']):
        data.append([float(row['LAT']), float(row['LONG'])])
        
HeatMap(data).add_to(map1)
map1.save(outfile='heatmap_test_coro.html')

map1

# %%
import folium
import math
from folium.plugins import MarkerCluster
import pandas as pd

map2 = folium.Map([19.2, -99.14], tiles='cartodbpositron', zoom_start=12)
marker_cluster = MarkerCluster().add_to(map2)

for index, row in data_confirmed.iterrows():
    if not math.isnan(row['LAT']) and not math.isnan(row['LONG']):
        description = str(row['PROCEDENCIA'] + ' ' + str(row['EDAD']))
        folium.Marker(location=[row['LAT'], row['LONG']], popup=description, icon = None).add_to(marker_cluster)
    
map2.save(outfile='marker_test.html')

map2

# %%
import folium
import math
from folium.plugins import MarkerCluster
import pandas as pd

#map3 = folium.Map([19.44244244,-99.1309882], tiles='cartodbpositron', zoom_start=5)
map3 = folium.Map([23.0224614, -101.4385219], tiles=None, zoom_start=4.5)
#folium.TileLayer('cartodbpositron', name='Casos sospechosos').add_to(map3)
folium.TileLayer('cartodbpositron', name='CartoDbPositron', overlay=True, show=True).add_to(map3)
folium.TileLayer('OpenStreetMap', name='OpenStreetMap', overlay=True, show=False).add_to(map3)


#data = []
#for index, row in data_confirmed.iterrows():
#    if not math.isnan(row['LAT']) and not math.isnan(row['LONG']):
#        data.append([float(row['LAT']), float(row['LONG'])])
#HeatMap(data, name="Mapa de calor (TODOS)", show=False).add_to(map3)


marker_cluster = MarkerCluster(name="Todos", show=True, overlay=False).add_to(map3)
for index, row in data_confirmed.iterrows():
    if not math.isnan(row['LAT']) and not math.isnan(row['LONG']):
        description = str('Procedencia: ' + row['PROCEDENCIA'] + '\nEdad: ' + str(row['EDAD']) + '\nSexo: ' + str(row['SEXO']) )
        folium.Marker(location=[row['LAT'], row['LONG']], popup=description, icon = None).add_to(marker_cluster)


marker_cluster_2 = MarkerCluster(name="Hombres", show=False, overlay=False).add_to(map3)
for index, row in data_confirmed.iterrows():
    if not math.isnan(row['LAT']) and not math.isnan(row['LONG']) and row['SEXO'] == 'M':
        description = str('Procedencia: ' + row['PROCEDENCIA'] + '\nEdad: ' + str(row['EDAD']) + '\nSexo: ' + str(row['SEXO']))
        folium.Marker(location=[row['LAT'], row['LONG']], popup=description, icon = None).add_to(marker_cluster_2)

        
# MUJERES
marker_cluster_2 = MarkerCluster(name="Mujeres", show=False, overlay=False).add_to(map3)
for index, row in data_confirmed.iterrows():
    if not math.isnan(row['LAT']) and not math.isnan(row['LONG']) and row['SEXO'] == 'F':
        description = str('Procedencia: ' + row['PROCEDENCIA'] + '\nEdad: ' + str(row['EDAD']) + '\nSexo: ' + str(row['SEXO']))
        folium.Marker(location=[row['LAT'], row['LONG']], popup=description, icon = None).add_to(marker_cluster_2)
    
# 0 a 10
marker_cluster_2 = MarkerCluster(name="0 a 10 años", show=False, overlay=False).add_to(map3)
for index, row in data_confirmed.iterrows():
    if not math.isnan(row['LAT']) and not math.isnan(row['LONG']) and row['EDAD'] <= 10:
        description = str('Procedencia: ' + row['PROCEDENCIA'] + '\nEdad: ' + str(row['EDAD']) + '\nSexo: ' + str(row['SEXO']))
        folium.Marker(location=[row['LAT'], row['LONG']], popup=description, icon = None).add_to(marker_cluster_2)
    
# 11 a 20
marker_cluster_2 = MarkerCluster(name="11 a 20 años", show=False, overlay=False).add_to(map3)
for index, row in data_confirmed.iterrows():
    if not math.isnan(row['LAT']) and not math.isnan(row['LONG']) and row['EDAD'] >= 11 and row['EDAD'] <= 20:
        description = str('Procedencia: ' + row['PROCEDENCIA'] + '\nEdad: ' + str(row['EDAD']) + '\nSexo: ' + str(row['SEXO']))
        folium.Marker(location=[row['LAT'], row['LONG']], popup=description, icon = None).add_to(marker_cluster_2)
    
# 21 a 30
marker_cluster_2 = MarkerCluster(name="21 a 30 años", show=False, overlay=False).add_to(map3)
for index, row in data_confirmed.iterrows():
    if not math.isnan(row['LAT']) and not math.isnan(row['LONG']) and row['EDAD'] >= 21 and row['EDAD'] <= 30:
        description = str('Procedencia: ' + row['PROCEDENCIA'] + '\nEdad: ' + str(row['EDAD']) + '\nSexo: ' + str(row['SEXO']))
        folium.Marker(location=[row['LAT'], row['LONG']], popup=description, icon = None).add_to(marker_cluster_2)

# 31 a 40
marker_cluster_2 = MarkerCluster(name="31 a 40 años", show=False, overlay=False).add_to(map3)
for index, row in data_confirmed.iterrows():
    if not math.isnan(row['LAT']) and not math.isnan(row['LONG']) and row['EDAD'] >= 31 and row['EDAD'] <= 40:
        description = str('Procedencia: ' + row['PROCEDENCIA'] + '\nEdad: ' + str(row['EDAD']) + '\nSexo: ' + str(row['SEXO']))
        folium.Marker(location=[row['LAT'], row['LONG']], popup=description, icon = None).add_to(marker_cluster_2)
        
# 41 a 50
marker_cluster_2 = MarkerCluster(name="41 a 50 años", show=False, overlay=False).add_to(map3)
for index, row in data_confirmed.iterrows():
    if not math.isnan(row['LAT']) and not math.isnan(row['LONG']) and row['EDAD'] >= 41 and row['EDAD'] <= 50:
        description = str('Procedencia: ' + row['PROCEDENCIA'] + '\nEdad: ' + str(row['EDAD']) + '\nSexo: ' + str(row['SEXO']))
        folium.Marker(location=[row['LAT'], row['LONG']], popup=description, icon = None).add_to(marker_cluster_2)
        
# 51 a 60
marker_cluster_2 = MarkerCluster(name="51 a 60 años", show=False, overlay=False).add_to(map3)
for index, row in data_confirmed.iterrows():
    if not math.isnan(row['LAT']) and not math.isnan(row['LONG']) and row['EDAD'] >= 51 and row['EDAD'] <= 60:
        description = str('Procedencia: ' + row['PROCEDENCIA'] + '\nEdad: ' + str(row['EDAD']) + '\nSexo: ' + str(row['SEXO']))
        folium.Marker(location=[row['LAT'], row['LONG']], popup=description, icon = None).add_to(marker_cluster_2)
        
# 61 a 70
marker_cluster_2 = MarkerCluster(name="61 a 70 años", show=False, overlay=False).add_to(map3)
for index, row in data_confirmed.iterrows():
    if not math.isnan(row['LAT']) and not math.isnan(row['LONG']) and row['EDAD'] >= 61 and row['EDAD'] <= 70:
        description = str('Procedencia: ' + row['PROCEDENCIA'] + '\nEdad: ' + str(row['EDAD']) + '\nSexo: ' + str(row['SEXO']))
        folium.Marker(location=[row['LAT'], row['LONG']], popup=description, icon = None).add_to(marker_cluster_2)
        
# 71 a 80
marker_cluster_2 = MarkerCluster(name="71 a 80 años", show=False, overlay=False).add_to(map3)
for index, row in data_confirmed.iterrows():
    if not math.isnan(row['LAT']) and not math.isnan(row['LONG']) and row['EDAD'] >= 71 and row['EDAD'] <= 80:
        description = str('Procedencia: ' + row['PROCEDENCIA'] + '\nEdad: ' + str(row['EDAD']) + '\nSexo: ' + str(row['SEXO']))
        folium.Marker(location=[row['LAT'], row['LONG']], popup=description, icon = None).add_to(marker_cluster_2)
        
# 81 a 90
marker_cluster_2 = MarkerCluster(name="81 a 90 años", show=False, overlay=False).add_to(map3)
for index, row in data_confirmed.iterrows():
    if not math.isnan(row['LAT']) and not math.isnan(row['LONG']) and row['EDAD'] >= 81 and row['EDAD'] <= 90:
        description = str('Procedencia: ' + row['PROCEDENCIA'] + '\nEdad: ' + str(row['EDAD']) + '\nSexo: ' + str(row['SEXO']))
        folium.Marker(location=[row['LAT'], row['LONG']], popup=description, icon = None).add_to(marker_cluster_2)
        
# 91 y más
marker_cluster_2 = MarkerCluster(name="91 años y más", show=False, overlay=False).add_to(map3)
for index, row in data_confirmed.iterrows():
    if not math.isnan(row['LAT']) and not math.isnan(row['LONG']) and row['EDAD'] >= 91:
        description = str('Procedencia: ' + row['PROCEDENCIA'] + '\nEdad: ' + str(row['EDAD']) + '\nSexo: ' + str(row['SEXO']))
        folium.Marker(location=[row['LAT'], row['LONG']], popup=description, icon = None).add_to(marker_cluster_2)
        
# GEOJSON ESTADOS
folium.GeoJson(
    "Mexico_Estados.geojson",
    name='geojson'
).add_to(map3)
        
folium.LayerControl(collapsed=True).add_to(map3)
    
#map3.save(outfile='multi_test_sospechosos.html')
map3.save(outfile='confirmados.html')

map3
